# %% [markdown]
# # Association Analysis
# Optimizing the sales of a grocery store

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

dataset = pd.read_csv('Market_Basket_Optimisation.csv', header = None)

# %%
dataset.head()
# Out:
#               0          1           2                 3             4   \
# 0         shrimp    almonds     avocado    vegetables mix  green grapes
# 1        burgers  meatballs        eggs               NaN           NaN
# 2        chutney        NaN         NaN               NaN           NaN
# 3         turkey    avocado         NaN               NaN           NaN
# 4  mineral water       milk  energy bar  whole wheat rice     green tea
#
#                  5     6               7             8             9   \
# 0  whole weat flour  yams  cottage cheese  energy drink  tomato juice
# 1               NaN   NaN             NaN           NaN           NaN
# 2               NaN   NaN             NaN           NaN           NaN
# 3               NaN   NaN             NaN           NaN           NaN
# 4               NaN   NaN             NaN           NaN           NaN
#
#                10         11     12     13             14      15  \
# ...

# %%
dataset.describe()
# Out:
#                    0              1              2              3          4   \
# count            7501           5747           4389           3345       2529
# unique            115            117            115            114        110
# top     mineral water  mineral water  mineral water  mineral water  green tea
# freq              577            484            375            201        153
#
#                   5          6          7          8          9   \
# count           1864       1369        981        654        395
# unique           106        102         98         88         80
# top     french fries  green tea  green tea  green tea  green tea
# freq             107         96         67         57         31
#
#                     10         11         12         13         14  \
# count              256        154         87         47         25
# unique              66         50         43         28         19
# ...

# %% [raw]
# # KWARGS
# min_support -
#  assumption: consider only the products purchased 3x a day = 3x7/7500 = 0.0028
# min_confidence - this rule
#  not the most pruchase all the time but to check the association is okay.
#  mineral water and eggs. we will get this if confidence is to high
# min_lift - this will give good insigh on the strength of the association
# min_length - minimum product to associate

# %%
transactions = []
for i in range(0, 7501):
    transactions.append([str(dataset.values[i,j]) for j in range(0, 20)])

# Training Apriori on the dataset
from apyori import apriori
rules = apriori(transactions, min_support = 0.003, min_confidence = 0.2, min_lift = 3, min_length = 2)

# %%
print(rules)
# Out:
# <generator object apriori at 0x000002A4F13ED258>

# %%
tran_df = pd.DataFrame(transactions)
tran_df
# Out:
#                      0                  1                  2   \
# 0                shrimp            almonds            avocado
# 1               burgers          meatballs               eggs
# 2               chutney                nan                nan
# 3                turkey            avocado                nan
# 4         mineral water               milk         energy bar
# 5        low fat yogurt                nan                nan
# 6     whole wheat pasta       french fries                nan
# 7                  soup        light cream            shallot
# 8     frozen vegetables          spaghetti          green tea
# 9          french fries                nan                nan
# 10                 eggs           pet food                nan
# 11              cookies                nan                nan
# 12               turkey            burgers      mineral water
# 13            spaghetti          champagne            cookies
# ...

# %%
df = pd.DataFrame(rules)

# %%
df
# Out:
#                                                  items   support  \
# 0                               (light cream, chicken)  0.004533
# 1                     (escalope, mushroom cream sauce)  0.005733
# 2                                    (escalope, pasta)  0.005866
# 3                               (fromage blanc, honey)  0.003333
# 4                         (herb & pepper, ground beef)  0.015998
# 5                          (tomato sauce, ground beef)  0.005333
# 6                             (light cream, olive oil)  0.003200
# 7                       (whole wheat pasta, olive oil)  0.007999
# 8                                      (pasta, shrimp)  0.005066
# 9                           (spaghetti, avocado, milk)  0.003333
# 10                               (cake, burgers, milk)  0.003733
# 11                        (turkey, chocolate, burgers)  0.003066
# 12                             (turkey, burgers, milk)  0.003200
# ...
